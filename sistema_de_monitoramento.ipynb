# %% [markdown]
# <a href="https://colab.research.google.com/github/Leticia-web10/sistema-de-monitoramento-de-tanque-de-gua/blob/main/sistema_de_monitoramento.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from datetime import datetime

# %%
#issue 01
class Tanque:

    def __init__(self, capacidade):
        self.capacidade = capacidade
        self.nivel_atual = 0

    def atualizar_nivel(self, nivel):
        self.nivel_atual = nivel

class Medicao:
    def __init__(self, nivel_agua, consumo_energia):
        self.data_hora = datetime.now()
        self.nivel_agua = nivel_agua
        self.consumo_energia = consumo_energia

class Alerta:

    def verificar(self, nivel, consumo):

        if nivel < 20:
            print(" Nível de água baixo!")

        if consumo > 100:
            print(" Consumo de energia acima do esperado!")

# %%
import matplotlib.pyplot as plt

class Tanque:
    def __init__(self, nome, capacidade, lista=[1000, 2000, 5000, 10000]):
        self.nome = nome
        self.capacidade = capacidade
        self.nivel_atual = 0
        self.conjunto = lista

    def simular(self, tempo):
        tempos = []
        niveis = []

        for i, nivel in enumerate(self.conjunto):
            self.nivel_atual = nivel
            print(f"Medição {i+1}: {self.nivel_atual} litros")

            tempos.append(i + 1)
            niveis.append(self.nivel_atual)

        plt.plot(tempos, niveis, marker='o')
        plt.title("Nível de Água do Tanque")
        plt.xlabel("Medição")
        plt.ylabel("Nível (litros)")
        plt.grid(True)
        plt.show()

    def atualizar_nivel(self, novo_nivel):
        self.nivel_atual = novo_nivel

    def mostrar_nivel(self):
        print(f"Nível atual do tanque: {self.nivel_atual} litros")


# Teste
tanque = Tanque("Caixa d'água", 10000)

tanque.atualizar_nivel(650)
tanque.mostrar_nivel()

tanque.simular()
# Out:
# Nível atual do tanque: 650 litros
# Medição 1: 1000 litros
# Medição 2: 2000 litros
# Medição 3: 5000 litros
# Medição 4: 10000 litros
